# %%
import pandas as pd
#read csv
df =pd.read_csv('data/finaltrain.csv')
#head - 1st 5 rows
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
#  12  Road_traffic_density         44983 non-null  object
#  13  Vehicle_condition            45584 non-null  int64
#  14  Type_of_order                45584 non-null  object
#  15  Type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  Festival                     45356 non-null  object
#  18  City                         44384 non-null  object
#  19  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %%
#Missing value check
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
#No mising values values

# %%
#Duplicate check
df.duplicated().sum()
# Out:
# 0

# %%
#No duplicated value

# %%
#Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
#  12  Road_traffic_density         44983 non-null  object
#  13  Vehicle_condition            45584 non-null  int64
#  14  Type_of_order                45584 non-null  object
#  15  Type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  Festival                     45356 non-null  object
#  18  City                         44384 non-null  object
#  19  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %%
#Drop Id column since it has no influence in results

# %%
df_back=df.copy()
df=df.drop(labels=["id"],axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_back=df.copy()
#       2 df=df.drop(labels=["id"],axis=1)
#       3 df.head()
#
# NameError: name 'df' is not defined

# %%
#segregate numerical & categorical columns
numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
numerical_columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)'],
#       dtype='object')

# %%
categorical_columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
df[numerical_columns].describe()
# Out:
#                carat          depth          table              x
# count  193573.000000  193573.000000  193573.000000  193573.000000  \
# mean        0.790688      61.820574      57.227675       5.715312
# std         0.462688       1.081704       1.918844       1.109422
# min         0.200000      52.100000      49.000000       0.000000
# 25%         0.400000      61.300000      56.000000       4.700000
# 50%         0.700000      61.900000      57.000000       5.700000
# 75%         1.030000      62.400000      58.000000       6.510000
# max         3.500000      71.600000      79.000000       9.650000
#
#                    y              z          price
# count  193573.000000  193573.000000  193573.000000
# mean        5.720094       3.534246    3969.155414
# std         1.102333       0.688922    4034.374138
# min         0.000000       0.000000     326.000000
# 25%         4.710000       2.900000     951.000000
# 50%         5.720000       3.530000    2401.000000
# 75%         6.510000       4.030000    5408.000000
# max        10.010000      31.300000   18818.000000

# %%
df[categorical_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   cut      193573 non-null  object
#  1   color    193573 non-null  object
#  2   clarity  193573 non-null  object
# dtypes: object(3)
# memory usage: 4.4+ MB

# %%
df[numerical_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   carat   193573 non-null  float64
#  1   depth   193573 non-null  float64
#  2   table   193573 non-null  float64
#  3   x       193573 non-null  float64
#  4   y       193573 non-null  float64
#  5   z       193573 non-null  float64
#  6   price   193573 non-null  int64
# dtypes: float64(6), int64(1)
# memory usage: 10.3 MB

# %%
df['cut'].unique()#'cut', 'color', 'clarity
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
df['cut'].value_counts()#'cut', 'color', 'clarity
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
#Histogram for numerical  columns
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()

# %%
#Categorical Plots
for i in categorical_columns:
    plt.figure(figsize=(5,5))
    sns.countplot(x =i, data = df)
    print('\n')
    plt.show()

# %%
#Strip plot - categorical columns
for i in categorical_columns:
    plt.figure(figsize=(5,5))
    sns.stripplot(x =i, y ='price', data = df, jitter = True, dodge = True)
    print('\n')
    plt.show()

# %%
#correlation
#sns.heatmap(df.corr(),annot=True)
#df.corr()
categorical_columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
cur_map={'Ideal':1,'Premium':2,'Very Good':3,'Good':4,'Fair':5}
df['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
color_map={'G':1,'E':2,'F':3,'H':4,'D':5,'I':6,'J':7}
df['clarity'].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}
df['color'].unique()
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}
df['color'].unique()
color_map= {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}
df['clarity'].unique()
color_map={"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}
clarity_map={"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}

# %%
#map the dict fpr the categories to df
df['color']=df['color'].map(color_map)
df['clarity']=df['clarity'].map(clarity_map)
df['cut']=df['cut'].map(cut_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453

# %%
#correlation
df.corr()
# Out:
#             carat       cut     color   clarity     depth     table         x
# carat    1.000000 -0.150901  0.292400 -0.348611  0.027852  0.225737  0.980563  \
# cut     -0.150901  1.000000 -0.022439  0.185145 -0.249720 -0.480481 -0.146743
# color    0.292400 -0.022439  1.000000  0.088333  0.035517  0.034978  0.269394
# clarity -0.348611  0.185145  0.088333  1.000000 -0.060720 -0.184567 -0.375424
# depth    0.027852 -0.249720  0.035517 -0.060720  1.000000 -0.230631 -0.010762
# table    0.225737 -0.480481  0.034978 -0.184567 -0.230631  1.000000  0.237578
# x        0.980563 -0.146743  0.269394 -0.375424 -0.010762  0.237578  1.000000
# y        0.980161 -0.147164  0.269509 -0.373709 -0.011653  0.233299  0.999109
# z        0.974274 -0.168376  0.270132 -0.376404  0.081821  0.212208  0.989724
# price    0.943396 -0.090948  0.210859 -0.184439  0.001880  0.174915  0.901004
#
#                 y         z     price
# carat    0.980161  0.974274  0.943396
# cut     -0.147164 -0.168376 -0.090948
# color    0.269509  0.270132  0.210859
# clarity -0.373709 -0.376404 -0.184439
# depth   -0.011653  0.081821  0.001880
# table    0.233299  0.212208  0.174915
# x        0.999109  0.989724  0.901004
# y        1.000000  0.989527  0.901033
# z        0.989527  1.000000  0.893037
# price    0.901033  0.893037  1.000000

# %%
#Heatmap
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >
